# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# LOADING DATABASE

# %%
retail_df = pd.read_csv("/content/Kraftora.csv")

# %%
display(retail_df.head())
# Out:
#    Invoice Month StockCode          Description        Name InvoiceDate Price  \
# 0   489434  June     85048  Hot wheels Bouquet   Dakshithaa  19.06.2025   350
# 1   489434  June    79323P    Polaroids Bouquet      Soniya  16.06.2025   400
# 2   489434  June    79323W    Polaroids Bouquet      Tamana  14.06.2025   400
# 3   489434  June     22041           Mini Frame    Darshana  16.06.2025   180
# 4   489434  June     21232           Mini Frame     Tharuna  20.06.2025   200
#
#    Customer ID Country
# 0        13085   India
# 1        13085   India
# 2        13085   India
# 3        13085   India
# 4        13085   India

# %%
retail_df.head(10)
# Out:
#    Invoice Month StockCode          Description        Name InvoiceDate Price  \
# 0   489434  June     85048  Hot wheels Bouquet   Dakshithaa  19.06.2025   350
# 1   489434  June    79323P    Polaroids Bouquet      Soniya  16.06.2025   400
# 2   489434  June    79323W    Polaroids Bouquet      Tamana  14.06.2025   400
# 3   489434  June     22041           Mini Frame    Darshana  16.06.2025   180
# 4   489434  June     21232           Mini Frame     Tharuna  20.06.2025   200
# 5   489434  June     22064           Big Hamper   Bagavathi  25.06.2025   550
# 6   489434  June     21871           Mini Frame    Sapthami  25.06.2025   180
# 7   489434  June     21523          Mini Hamper  Mohan Bhai  28.06.2025   350
# 8   489435  June     22350           Mini Frame    Sindhuja  30.06.2025   180
# 9   489435  June     22349            Polaroids     Tanisha  27.06.2025   120
#
#    Customer ID Country
# 0        13085   India
# 1        13085   India
# 2        13085   India
# ...

# %%
print("Shape:", retail_df.shape)
# Out:
# Shape: (132, 9)

# %%
print("Shape:", retail_df.shape)
# Out:
# Shape: (132, 9)

# %%
retail_df.tail(5)
# Out:
#      Invoice    Month StockCode    Description      Name InvoiceDate Price  \
# 127   489445  January    35916C       A4 Frame       Anu  20.01.2026   600
# 128   489445  January    35916B      Polaroids   Harini   20.01.2026    95
# 129   489445  January     22321     Mini Frame  Angellin  20.01.2026   200
# 130   489445  January     22130  Custom Hamper  Pradeepa  21.01.2026   430
# 131   489445  January     22180     Mini Frame  Kowsalya  21.01.2026   400
#
#      Customer ID Country
# 127        17519   India
# 128        17519   India
# 129        17519   India
# 130        17519   India
# 131        17519   India

# %%
#Display first 5 rows [0->4]
retail_df.head()
# Out:
#    Invoice Month StockCode          Description        Name InvoiceDate Price  \
# 0   489434  June     85048  Hot wheels Bouquet   Dakshithaa  19.06.2025   350
# 1   489434  June    79323P    Polaroids Bouquet      Soniya  16.06.2025   400
# 2   489434  June    79323W    Polaroids Bouquet      Tamana  14.06.2025   400
# 3   489434  June     22041           Mini Frame    Darshana  16.06.2025   180
# 4   489434  June     21232           Mini Frame     Tharuna  20.06.2025   200
#
#    Customer ID Country
# 0        13085   India
# 1        13085   India
# 2        13085   India
# 3        13085   India
# 4        13085   India

# %%
retail_df.iloc[0:5]
# Out:
#    Invoice Month StockCode          Description        Name InvoiceDate Price  \
# 0   489434  June     85048  Hot wheels Bouquet   Dakshithaa  19.06.2025   350
# 1   489434  June    79323P    Polaroids Bouquet      Soniya  16.06.2025   400
# 2   489434  June    79323W    Polaroids Bouquet      Tamana  14.06.2025   400
# 3   489434  June     22041           Mini Frame    Darshana  16.06.2025   180
# 4   489434  June     21232           Mini Frame     Tharuna  20.06.2025   200
#
#    Customer ID Country
# 0        13085   India
# 1        13085   India
# 2        13085   India
# 3        13085   India
# 4        13085   India

# %%
retail_df.columns
# Out:
# Index(['Invoice', 'Month', 'StockCode', 'Description', 'Name', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
#to Get information of data
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Invoice      132 non-null    int64
#  1   Month        132 non-null    object
#  2   StockCode    132 non-null    object
#  3   Description  132 non-null    object
#  4   Name         132 non-null    object
#  5   InvoiceDate  132 non-null    object
#  6   Price        132 non-null    object
#  7   Customer ID  132 non-null    int64
#  8   Country      132 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 9.4+ KB

# %% [markdown]
# **Missing Values Summary**

# %%
# Missing values
print(retail_df.isna().sum())
# Out:
# Invoice        0
# Month          0
# StockCode      0
# Description    0
# Name           0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
# Unique values in each column
print(retail_df.nunique())
# Out:
# Invoice         12
# Month            8
# StockCode      117
# Description     38
# Name            72
# InvoiceDate     89
# Price           48
# Customer ID     10
# Country          1
# dtype: int64

# %%
# Missing Values Calculation
retail_df.isnull().sum()
# Out:
# Invoice        0
# Month          0
# StockCode      0
# Description    0
# Name           0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# dtype: int64

# %%
# calculate the percentage of missing values in each column
(retail_df.isnull().sum()/(len(retail_df)))*100
# Out:
# Invoice        0.0
# Month          0.0
# StockCode      0.0
# Description    0.0
# Name           0.0
# InvoiceDate    0.0
# Price          0.0
# Customer ID    0.0
# Country        0.0
# dtype: float64

# %% [markdown]
# **DUPLICATE FINDINGS**

# %%
# Duplicate Records

# Countig the duplicates
duplicate_count = retail_df.duplicated().sum()
print("Total Duplicate Rows:", duplicate_count)

# Display sample duplicates
if duplicate_count > 0:
    display(retail_df[retail_df.duplicated()].head())

# Removing duplicates values
retail_df = retail_df.drop_duplicates()
print("\nDuplicates removed. New shape:", retail_df.shape)
# Out:
# Total Duplicate Rows: 0
#
# Duplicates removed. New shape: (132, 9)

# %% [markdown]
# Detect Outliers

# %%
num_cols = retail_df.select_dtypes(include=['int64', 'float64']).columns

total_outliers = 0  # To count total outliers in dataset
outlier_details = {}  # To store which column has outliers

for col in num_cols:
    Q1 = retail_df[col].quantile(0.25)
    Q3 = retail_df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = retail_df[(retail_df[col] < lower) | (retail_df[col] > upper)]
    count = len(outliers)

    if count > 0:
        outlier_details[col] = count
        total_outliers += count

# ===========================
#       FINAL OUTPUT
# ===========================

if total_outliers > 0:
    print(f"\nTotal Outliers in Entire Dataset: {total_outliers}\n")
    print("Columns with Outliers:")
    for col, cnt in outlier_details.items():
        print(f"- {col}: {cnt} outliers")
else:
    print("✅ No outliers found in the entire dataset!")
# Out:
# ✅ No outliers found in the entire dataset!

# %% [markdown]
# Finding Inconsistent Records – Negative Values (retail_df)

# %%
import numpy as np

# Convert 'Price' column to numeric, coercing errors to NaN
retail_df['Price'] = pd.to_numeric(retail_df['Price'], errors='coerce')

# Fill any NaN values in 'Price' that resulted from conversion, e.g., with 0 or the median
retail_df['Price'] = retail_df['Price'].fillna(0) # or retail_df['Price'].median()

# Create 'Quantity_numeric' column if it doesn't exist.
# Assuming a default quantity of 1 if no explicit quantity column is available.
# You might need to adjust this based on your dataset's original quantity column.
if 'Quantity_numeric' not in retail_df.columns:
    retail_df['Quantity_numeric'] = 1 # Placeholder value
    print("Note: 'Quantity_numeric' column was created and initialized to 1 as it was missing. Please adjust if your data contains actual quantity values.")

negative_quantity = retail_df[retail_df['Quantity_numeric'] < 0]

if not negative_quantity.empty:
    print("Rows with negative 'Quantity_numeric' values:")
    display(negative_quantity.head())
    print(f"Total rows with negative 'Quantity_numeric': {len(negative_quantity)}")
else:
    print("No negative values found in 'Quantity_numeric' column.")
# Out:
# Note: 'Quantity_numeric' column was created and initialized to 1 as it was missing. Please adjust if your data contains actual quantity values.
# No negative values found in 'Quantity_numeric' column.

# %%
#Inconsistent categories
print("Unique values and their counts for 'Country':")
display(retail_df['Country'].value_counts())
# Out:
# Unique values and their counts for 'Country':
# Country
# India    132
# Name: count, dtype: int64

# %%
print("Top 50 unique values and their counts for 'Description':")
display(retail_df['Description'].value_counts().head(50))
print(f"Total unique descriptions: {retail_df['Description'].nunique()}")
# Out:
# Top 50 unique values and their counts for 'Description':
# Description
# Mini Frame                       29
# Polaroids                        21
# Custom Hamper                    11
# Big Hamper                        7
# Mini frame + Polaroids            5
# Mini Hamper                       5
# A4 Frame                          5
# Polaroids Bouquet                 4
# 8x6 Frames                        4
# Mini Frames                       3
# Special Hamper                    3
# Hot wheels Bouquet                2
# Strips and Cards                  2
# Frame + Polaroids                 2
# Stickers                          2
# 8x6 Frame                         2
# Chocolate Bouquet                 2
# Custom Pack                       2
# Ring Album                        2
# Polaroids Book                    1
# Mini Bouquet + Polaroids          1
# Kinderjoy Bouquet                 1
# Mini frame                        1
# Custom Bouquet + Polaroids        1
# ...

# %% [markdown]
# ## Visualization of TotalPrice Distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure 'InvoiceDate' is datetime for consistency, though not directly used for TotalPrice calculation here
retail_df['InvoiceDate'] = pd.to_datetime(retail_df['InvoiceDate'])

# Calculate 'TotalPrice' for each transaction if it doesn't already exist
# This line is added to ensure TotalPrice is available before plotting
retail_df['TotalPrice'] = retail_df['Quantity_numeric'] * retail_df['Price']

plt.figure(figsize=(14, 6))

# Histogram for TotalPrice
plt.subplot(1, 2, 1)
sns.histplot(retail_df['TotalPrice'], kde=True, bins=50)
plt.title('Distribution of TotalPrice')
plt.xlabel('TotalPrice')
plt.ylabel('Frequency')

# Box plot for TotalPrice
plt.subplot(1, 2, 2)
sns.boxplot(y=retail_df['TotalPrice'])
plt.title('Box Plot of TotalPrice')
plt.ylabel('TotalPrice')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Derived Metrics

# %%
# Convert 'InvoiceDate' to datetime objects
retail_df['InvoiceDate'] = pd.to_datetime(retail_df['InvoiceDate'])

# Calculate 'TotalPrice' for each transaction
retail_df['TotalPrice'] = retail_df['Quantity_numeric'] * retail_df['Price']

# Display the DataFrame with the new 'TotalPrice' column
print("Retail DataFrame with 'TotalPrice' column:")
display(retail_df.head())
# Out:
# Retail DataFrame with 'TotalPrice' column:
#    Invoice Month StockCode          Description        Name InvoiceDate  \
# 0   489434  June     85048  Hot wheels Bouquet   Dakshithaa  2025-06-19
# 1   489434  June    79323P    Polaroids Bouquet      Soniya  2025-06-16
# 2   489434  June    79323W    Polaroids Bouquet      Tamana  2025-06-14
# 3   489434  June     22041           Mini Frame    Darshana  2025-06-16
# 4   489434  June     21232           Mini Frame     Tharuna  2025-06-20
#
#    Price  Customer ID Country  Quantity_numeric  TotalPrice
# 0  350.0        13085   India                 1       350.0
# 1  400.0        13085   India                 1       400.0
# 2  400.0        13085   India                 1       400.0
# 3  180.0        13085   India                 1       180.0
# 4  200.0        13085   India                 1       200.0

# %% [markdown]
# ## Filtering Data for Targeted Analysis

# %% [markdown]
# DESCRIPTIVE STATISTICS

# %%
display(retail_df.describe())
# Out:
#              Invoice                    InvoiceDate       Price   Customer ID  \
# count     132.000000                            132  132.000000    132.000000
# mean   489438.742424  2025-10-11 06:32:43.636363520  286.363636  14610.969697
# min    489434.000000            2025-01-12 00:00:00    0.000000  12636.000000
# 25%    489437.000000            2025-08-09 18:00:00  180.000000  13078.000000
# 50%    489438.000000            2025-10-14 00:00:00  205.000000  13635.000000
# 75%    489442.000000            2025-11-28 06:00:00  400.000000  15362.000000
# max    489445.000000            2028-10-18 00:00:00  800.000000  18102.000000
# std         2.867617                            NaN  197.131230   1964.945929
#
#        Quantity_numeric  TotalPrice
# count             132.0  132.000000
# mean                1.0  286.363636
# min                 1.0    0.000000
# 25%                 1.0  180.000000
# 50%                 1.0  205.000000
# 75%                 1.0  400.000000
# ...

# %% [markdown]
# # Task

# %% [markdown]
# ##Descriptive Statistics

# %%
# Create 'StockCode_length' and 'StockCode_word_count' columns if they don't exist
if 'StockCode_length' not in retail_df.columns:
    retail_df['StockCode_length'] = retail_df['StockCode'].astype(str).apply(len)
    print("Created 'StockCode_length' column.")

if 'StockCode_word_count' not in retail_df.columns:
    retail_df['StockCode_word_count'] = retail_df['StockCode'].astype(str).apply(lambda x: len(str(x).split()))
    print("Created 'StockCode_word_count' column.")

numerical_cols_retail = ['Quantity_numeric', 'Price', 'TotalPrice', 'StockCode_length', 'StockCode_word_count']
descriptive_stats_retail = retail_df[numerical_cols_retail].describe()

print("Descriptive statistics for key numerical features in retail_df:")
display(descriptive_stats_retail)
# Out:
# Created 'StockCode_length' column.
# Created 'StockCode_word_count' column.
# Descriptive statistics for key numerical features in retail_df:
#        Quantity_numeric       Price  TotalPrice  StockCode_length  \
# count             132.0  132.000000  132.000000        132.000000
# mean                1.0  286.363636  286.363636          5.212121
# std                 0.0  197.131230  197.131230          0.446022
# min                 1.0    0.000000    0.000000          4.000000
# 25%                 1.0  180.000000  180.000000          5.000000
# 50%                 1.0  205.000000  205.000000          5.000000
# 75%                 1.0  400.000000  400.000000          5.000000
# max                 1.0  800.000000  800.000000          6.000000
#
#        StockCode_word_count
# count                 132.0
# mean                    1.0
# std                     0.0
# min                     1.0
# 25%                     1.0
# 50%                     1.0
# ...

# %% [markdown]
# ## Univariate Analysis - Numerical Features

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols_retail = ['Quantity_numeric', 'Price', 'TotalPrice', 'StockCode_length', 'StockCode_word_count']

for col in numerical_cols_retail:
    print(f"\n--- Descriptive Statistics for {col} ---")
    display(retail_df[col].describe())

    plt.figure(figsize=(14, 6))

    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(retail_df[col], kde=True, bins=50)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

    # Box plot
    plt.subplot(1, 2, 2)
    sns.boxplot(y=retail_df[col])
    plt.title(f'Box Plot of {col}')
    plt.ylabel(col)

    plt.tight_layout()
    plt.show()
# Out:
# --- Descriptive Statistics for Quantity_numeric ---
# count    132.0
# mean       1.0
# std        0.0
# min        1.0
# 25%        1.0
# 50%        1.0
# 75%        1.0
# max        1.0
# Name: Quantity_numeric, dtype: float64
# --- Descriptive Statistics for Price ---
# count    132.000000
# mean     286.363636
# std      197.131230
# min        0.000000
# 25%      180.000000
# 50%      205.000000
# 75%      400.000000
# max      800.000000
# Name: Price, dtype: float64
# --- Descriptive Statistics for TotalPrice ---
# count    132.000000
# mean     286.363636
# std      197.131230
# min        0.000000
# 25%      180.000000
# 50%      205.000000
# 75%      400.000000
# max      800.000000
# Name: TotalPrice, dtype: float64
# --- Descriptive Statistics for StockCode_length ---
# count    132.000000
# mean       5.212121
# std        0.446022
# min        4.000000
# 25%        5.000000
# 50%        5.000000
# 75%        5.000000
# max        6.000000
# ...

# %% [markdown]
# ## Univariate Analysis - Categorical Features
#
# ### Subtask:

# %%
categorical_cols_retail = ['Country', 'Description']

for col in categorical_cols_retail:
    print(f"\n--- Value Counts for {col} ---")
    if col == 'Description':
        # Display top 30 descriptions for readability due to high cardinality
        value_counts = retail_df[col].value_counts().head(30)
        display(value_counts)

        plt.figure(figsize=(12, 7))
        sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
        plt.title(f'Top 30 Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Count')
        plt.xticks(rotation=90, ha='right')
        plt.tight_layout()
        plt.show()

    else:
        value_counts = retail_df[col].value_counts()
        display(value_counts)

        plt.figure(figsize=(12, 7))
        sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
        plt.title(f'Distribution of {col}')
        plt.xlabel(col)
        plt.ylabel('Count')
        plt.xticks(rotation=90, ha='right')
        plt.tight_layout()
        plt.show()
# Out:
# --- Value Counts for Country ---
# Country
# India    132
# Name: count, dtype: int64
# --- Value Counts for Description ---
# Description
# Mini Frame                       29
# Polaroids                        21
# Custom Hamper                    11
# Big Hamper                        7
# Mini frame + Polaroids            5
# Mini Hamper                       5
# A4 Frame                          5
# Polaroids Bouquet                 4
# 8x6 Frames                        4
# Mini Frames                       3
# Special Hamper                    3
# Hot wheels Bouquet                2
# Strips and Cards                  2
# Frame + Polaroids                 2
# Stickers                          2
# 8x6 Frame                         2
# Chocolate Bouquet                 2
# Custom Pack                       2
# Ring Album                        2
# Polaroids Book                    1
# Mini Bouquet + Polaroids          1
# Kinderjoy Bouquet                 1
# ...

# %% [markdown]
# ## Bivariate Analysis - Correlation Heatmap
#
# ### Subtask:

# %%
numerical_features = ['Quantity_numeric', 'Price', 'TotalPrice', 'StockCode_length', 'StockCode_word_count']

correlation_matrix = retail_df[numerical_features].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix of Numerical Features in retail_df')
plt.show()

# %% [markdown]
# ## Bivariate Analysis - Scatter Plots
#
# ### Subtask:

# %%
plt.figure(figsize=(14, 6))
sns.scatterplot(data=retail_df, x='Quantity_numeric', y='TotalPrice', alpha=0.5)
plt.title('Relationship between Quantity and Total Price')
plt.xlabel('Quantity (Numeric)')
plt.ylabel('Total Price')
plt.grid(True)
plt.show()

plt.figure(figsize=(14, 6))
sns.scatterplot(data=retail_df, x='Price', y='TotalPrice', alpha=0.5)
plt.title('Relationship between Price and Total Price')
plt.xlabel('Price')
plt.ylabel('Total Price')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get the top 10 countries by total transaction volume for better visualization
top_countries = retail_df['Country'].value_counts().nlargest(10).index
filtered_retail_df = retail_df[retail_df['Country'].isin(top_countries)]

plt.figure(figsize=(15, 8))
sns.boxplot(data=filtered_retail_df, x='Country', y='TotalPrice', palette='viridis')
plt.title('Distribution of Total Price by Top 10 Countries')
plt.xlabel('Country')
plt.ylabel('Total Price')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.tight_layout()
plt.show()
